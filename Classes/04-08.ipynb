# %%
import matplotlib.pyplot as plt
import numpy as np
import skimage
from skimage import data

# %%
im=data.astronaut()

plt.imshow(im)

# %%
im1=im[0:200,125:300]

plt.imshow(im1)

# %%
im2=im[:,:,1]

plt.imshow(im2)

# %%
im3=im[:,:,0]

plt.imshow(im3)

# %%
im4=im[:,:,2]

plt.imshow(im4)

# %%
a,b=np.split(im,2,axis=1)

plt.imshow(a)

# %%
plt.imshow(b)

# %%
c,d=np.split(im,2)

plt.imshow(c)

# %%
e,f,g=np.split(im,3,axis=2)

plt.imshow(e)

# %%
print(e)
print(im3)
# Out:
# [[[154]
#   [109]
#   [ 63]
#   ...
#   [127]
#   [120]
#   [125]]
#
#  [[177]
#   [144]
#   [113]
#   ...
#   [127]
#   [124]
#   [121]]
#
#  [[201]
#   [182]
#   [168]
#   ...
#   [128]
#   [126]
#   [124]]
#
#  ...
#
#  [[186]
#   [186]
#   [183]
#   ...
#   [  0]
#   [  0]
#   [  0]]
#
#  [[183]
#   [182]
#   [185]
#   ...
#   [  0]
#   [  1]
#   [  0]]
#
#  [[184]
#   [183]
#   [180]
#   ...
#   [  0]
#   [  1]
#   [  0]]]
# [[154 109  63 ... 127 120 125]
#  [177 144 113 ... 127 124 121]
#  [201 182 168 ... 128 126 124]
#  ...
#  [186 186 183 ...   0   0   0]
#  [183 182 185 ...   0   1   0]
#  [184 183 180 ...   0   1   0]]
